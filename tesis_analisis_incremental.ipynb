# %%
# !python tesis_analisis_incremental.py \
        --tensor-dir /home/diego/Escritorio/desde_cero/AAL3_Tesis_Refactored_v7_131ROIs_6Ch_ROIreordered/individual_tensors \
        --metadata /home/diego/Escritorio/desde_cero/SubjectsData_cleaned.csv \
        --roi-meta /home/diego/Escritorio/desde_cero/ROI_MNI_V7_vol.txt \
        --outdir ./resultados_analisis_incremental_$(date +%F_%H-%M)
# Out:
# 2025-06-18 17:03:33.245564: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-18 17:03:34.139949: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2025-06-18 17:03:35,729 - INFO - tesis_analisis_incremental.py:150 - --- 1.1: Reconstruyendo Metadatos desde la Configuración del Pipeline ---
# 2025-06-18 17:03:35,729 - INFO - pipeline.py:112 - --- Initializing Pipeline ---
# 2025-06-18 17:03:35,734 - INFO - pipeline.py:123 - Final expected ROI count after reductions: 131
# 2025-06-18 17:03:35,734 - INFO - pipeline.py:58 - Attempting to map AAL3 ROIs to Yeo-17 networks for reordering.
# ...
