# %%
# !python pipeline.py
# Out:
# 2025-06-18 16:25:37,079 - INFO - pipeline.py:112 - --- Initializing Pipeline ---
# 2025-06-18 16:25:37,083 - INFO - pipeline.py:123 - Final expected ROI count after reductions: 131
# 2025-06-18 16:25:37,083 - INFO - pipeline.py:58 - Attempting to map AAL3 ROIs to Yeo-17 networks for reordering.
# 2025-06-18 16:25:37,324 - WARNING - pipeline.py:71 - AAL3 and Yeo atlases do not match. Resampling AAL3 to Yeo space.
# 2025-06-18 16:27:09,239 - INFO - pipeline.py:134 - Connectivity channels to compute: ['Pearson_OMST_GCE_Signed_Weighted', 'Pearson_Full_FisherZ_Signed', 'MI_KNN_Symmetric', 'dFC_AbsDiffMean', 'dFC_StdDev', 'Granger_F_lag1']
# 2025-06-18 16:27:09,240 - INFO - pipeline.py:161 - --- Loading Cleaned Subject List ---
# 2025-06-18 16:27:09,243 - INFO - pipeline.py:191 - Successfully loaded 430 subjects to be processed.
# ...
